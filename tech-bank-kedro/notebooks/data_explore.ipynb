# %%
# %load_ext kedro.ipython
# Out:
# [05/26/24 19:11:56] INFO     Registered line magic '%reload_kedro'                                   ]8;id=855997;file://c:\Users\akili\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=377489;file://c:\Users\akili\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\ipython\__init__.py#51\51]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=189012;file://c:\Users\akili\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=331112;file://c:\Users\akili\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\ipython\__init__.py#53\53]8;;\
# ...

# %%
# %load_ext kedro.ipython
# Out:
# [05/26/24 18:56:17] INFO     Registered line magic '%reload_kedro'                                   ]8;id=170202;file://c:\Users\akili\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=714574;file://c:\Users\akili\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\ipython\__init__.py#51\51]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=519367;file://c:\Users\akili\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=221088;file://c:\Users\akili\AppData\Local\Programs\Python\Python311\Lib\site-packages\kedro\ipython\__init__.py#53\53]8;;\
# ...
